# %% [markdown]
# # Breast cancer

# %%
import pandas as pd
import jax
import jax.numpy as jnp
from sklearn.datasets import load_breast_cancer

# %% [markdown]
# ## Load data

# %%
data = load_breast_cancer()
bc_data = pd.DataFrame(data.data, columns=data.feature_names)
bc_data['target'] = data.target
bc_data['target'] = bc_data['target'].astype(int)
bc_data['diagnosis'] = bc_data['target'].map({ 0: 'malign', 1: 'benign'})

# %%
bc_data.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst perimeter  worst area  worst smoothness  \
# 0                 0.07871  ...           184.60      2019.0            0.1622
# 1                 0.05667  ...           158.80      1956.0            0.1238
# 2                 0.05999  ...           152.50      1709.0            0.1444
# 3                 0.09744  ...            98.87       567.7            0.2098
# 4                 0.05883  ...           152.20      1575.0            0.1374
#
#    worst compactness  worst concavity  worst concave points  worst symmetry  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    worst fractal dimension  target  diagnosis
# 0                  0.11890       0     malign
# 1                  0.08902       0     malign
# 2                  0.08758       0     malign
# 3                  0.17300       0     malign
# 4                  0.07678       0     malign
#
# [5 rows x 32 columns]

# %%
X_wo_diagnosis = bc_data.drop(['target', 'diagnosis'], axis=1).astype(float).values
y_diagnosis = bc_data['target'].astype(float).values

# %% [markdown]
# ## Create seed and separate data

# %%
# creates te seed for random numbers befor spliting the data
seed = jax.random.PRNGKey(73)
index = jnp.arange(len(X_wo_diagnosis))
index_shuffle = jax.random.permutation(seed, index)

# %%
X_shuffle = X_wo_diagnosis[index_shuffle]
y_shuffle = y_diagnosis[index_shuffle]
split_index = int(len(X_shuffle) * 0.9) # calculate %90 of the total data

# %%
# separate %90 data for training
X_training = X_shuffle[:split_index]
y_training = y_shuffle[:split_index]

# data for test
X_test = X_shuffle[split_index:]
y_test = y_shuffle[split_index:]

# %%
X_training
# Out:
# array([[1.316e+01, 2.054e+01, 8.406e+01, ..., 4.195e-02, 2.687e-01,
#         7.429e-02],
#        [1.189e+01, 1.835e+01, 7.732e+01, ..., 1.138e-01, 3.397e-01,
#         8.365e-02],
#        [1.791e+01, 2.102e+01, 1.244e+02, ..., 1.964e-01, 3.245e-01,
#         1.198e-01],
#        ...,
#        [1.499e+01, 2.211e+01, 9.753e+01, ..., 1.308e-01, 3.163e-01,
#         9.251e-02],
#        [1.218e+01, 1.408e+01, 7.725e+01, ..., 1.852e-02, 2.293e-01,
#         6.037e-02],
#        [1.025e+01, 1.618e+01, 6.652e+01, ..., 9.744e-02, 2.608e-01,
#         9.702e-02]], shape=(512, 30))

# %% [markdown]
# ## Augmented Vector on training data

# %%
mid_vector = jnp.ones((X_training.shape[0], 1))
X_aug = jnp.concatenate([mid_vector, jnp.array(X_training)], axis=1)
y = jnp.array(y_training)
print(X_aug.shape)
# Out:
# (512, 31)

# %%
XtX = X_aug.T @ X_aug # @ is the dot product, and is equal to use jnp.dot()
Xty = X_aug.T @ y
beta = jnp.linalg.solve(XtX, Xty) # linalg is linear algebra. It uses decomposition to solve the equation instead to use the direct inv

# %%
# beta

#         1.1047708 ,  1.3565851 ,  0.0817253 ,  0.86526483,  0.8042351 ,
#        -0.21419385,  0.22027922,  0.19561884,  0.57764554,  1.0025364 ,
#         0.9625113 ,  1.1904149 ,  0.70242506,  0.43515798,  0.3576563 ,
#         0.09152922,  0.15819621,  0.7878181 ,  0.32255214,  0.8817806 ,
#         0.8647079 ,  0.9085281 ,  0.4555304 , -0.07976446,  0.10716885,
#         0.60184264, -0.03459176,  0.24004719,  0.44995704,  0.06853947,
#         1.1042538 ,  1.0409396 , -0.22110912,  0.24670336,  0.18305472,
#        -0.03382516,  0.11606002,  0.83092874,  0.79114544, -0.14630249,
#         1.0220433 ,  0.45903468,  1.0566653 ,  0.84582835,  0.09404942,
#         1.0258577 ,  0.45643643,  1.1639249 ,  0.9438049 ,  0.11075884,
#         1.1871163 ,  0.30847508,  0.10478687,  0.76443595, -0.14493027,
#         1.0602282 ,  0.91963446,  1.1624587 ,  0.18800825, -0.08891606,
#         0.6902683 ,  0.75923645,  0.8909106 ,  0.8826555 ,  0.646351  ,
#         0.9035892 ,  0.9427866 ,  1.0230296 ,  0.9082182 ,  0.65119785,
#         1.2448542 ,  0.94548887, -0.01215944, -0.11663008,  0.7696701 ,
#         0.07327324,  0.80706286,  0.83625555,  0.98486763,  0.8412793 ,
#         0.864076  ,  0.95671344,  1.2596245 ,  0.7813773 ,  0.67855954,
#         1.014967  ,  0.92729425,  0.22385561,  1.1361209 ,  1.1402464 ,
#         1.0871645 ,  0.95230925,  0.9815576 ,  0.9735263 ,  0.63587886,
#         0.9273752 , -0.49488702, -0.08230123,  1.3346488 ,  1.0775957 ,
#         0.93282545,  0.8506821 ,  0.7926903 ,  0.1992966 ,  0.7110752 ,
#         1.1522826 ,  0.26582712,  0.51377904,  0.983755  ,  0.67095804,
#         1.0992213 ,  0.4258217 , -0.20394213,  0.98349327,  1.2593834 ,
#        -0.32824773, -0.05559289,  0.14747417,  0.8967338 ,  0.88494134,
#         0.6270545 , -0.12605435,  0.77855384,  0.3777454 ,  0.9071213 ,
#         0.8095945 ,  0.7072681 ,  0.6788331 ,  0.20739883,  0.02217582,
#        -0.11484575,  0.8540516 ,  1.0021174 ,  0.7105052 , -0.22367263,
#         0.62189263,  1.0473692 ,  0.00567639,  0.6700017 ,  0.57017136,
#         1.1517363 ,  0.88291687,  0.91436994,  0.7155777 ,  0.23898607,
#         0.13527516,  0.89629817, -0.00517073,  0.8874908 ,  0.74430346,
#        -0.02622169,  1.2993253 , -0.35311657, -0.15110505,  0.69623077,
#         0.6420698 ,  0.9910308 ,  0.91252476,  0.12781107,  0.46992677,
#         1.10343   ,  0.8778281 ,  0.49773443,  1.1293002 ,  0.5606265 ,
#         1.1634984 ,  0.9306387 ], dtype=float32)

# %% [markdown]
# ## Calculate error

# %%
res = y - y_hat
print(f'The average error is: {jnp.mean(jnp.abs(res))}')
mse = jnp.mean(jnp.power(res, 2))
rmse = jnp.sqrt(mse)
print(f'MSE: {mse}')
print(f'RMSE: {rmse}')
rss = jnp.sum(jnp.square(res))
y_med = jnp.mean(y)
ss_total = jnp.sum(jnp.square(y - y_med))
r2 = 1 - (rss / ss_total)
print(f'R² is : {r2}')
# Out:
# The average error is: 0.17772424221038818
# MSE: 0.05146179720759392
# RMSE: 0.2268519252538681
# R² is : 0.7769997119903564

# %%
y_labeled = ["benign" if val > 0.5 else "malign" for val in y_hat]

# %%
y_labeled
# Out:
# ['benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'malign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'malign',
#  'benign',
#  'malign',
#  'malign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'malign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign']

# %% [markdown]
# ## Test data

# %%
mid_vector = jnp.ones((X_test.shape[0], 1))
X_aug = jnp.concatenate([mid_vector, jnp.array(X_test)], axis=1)
y = jnp.array(y_test)
print(X_aug.shape)
# Out:
# (57, 31)

# %%
XtX = X_aug.T @ X_aug # @ is the dot product, and is equal to use jnp.dot()
Xty = X_aug.T @ y
beta = jnp.linalg.solve(XtX, Xty) # linalg is linear algebra. It uses decomposition to solve the equation instead to use the direct inv
y_hat = X_aug @ beta
y_hat
# Out:
# Array([ 1.01814270e-01,  2.75936425e-01,  5.84830642e-02,  9.73012567e-01,
#         2.52860904e-01,  1.18215895e+00,  1.07472634e+00,  1.09981275e+00,
#        -1.00225210e-02,  1.10297942e+00, -1.11077607e-01,  1.03498721e+00,
#         5.17105460e-02,  8.51636767e-01,  9.64229405e-01,  1.06419969e+00,
#         8.80276322e-01,  1.34629250e-01,  1.00183487e-01,  1.05677366e-01,
#         1.06290317e+00,  9.92781460e-01,  6.64166451e-01, -7.29326010e-02,
#         8.41149211e-01, -7.24412203e-02,  9.78482127e-01,  7.30124533e-01,
#        -1.33021235e-01,  8.36759150e-01,  3.03998351e-01,  3.45954895e-02,
#         3.46915573e-01,  6.83600903e-01,  2.31331587e-02,  1.41391635e-01,
#         1.13254309e+00,  9.80163574e-01,  6.55666709e-01,  1.01782620e-01,
#        -1.60896122e-01, -2.70078957e-01,  1.19922972e+00,  9.51718152e-01,
#         1.82604194e-01,  1.44466579e-01,  8.65396917e-01,  8.75677228e-01,
#        -3.10599804e-04,  7.52910733e-01, -1.89059794e-01, -8.81506205e-02,
#         1.02304208e+00,  1.04595578e+00,  8.09599698e-01,  1.18025899e+00,
#         2.25617677e-01], dtype=float32)

# %%
y_labeled = ["benign" if val > 0.5 else "malign" for val in y_hat]
y_labeled
# Out:
# ['malign',
#  'malign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'malign',
#  'malign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign']

# %% [markdown]
# ## Test error

# %%
res = y - y_hat
print(f'The average error is: {jnp.mean(jnp.abs(res))}')
mse = jnp.mean(jnp.power(res, 2))
rmse = jnp.sqrt(mse)
print(f'MSE: {mse}')
print(f'RMSE: {rmse}')
rss = jnp.sum(jnp.square(res))
y_med = jnp.mean(y)
ss_total = jnp.sum(jnp.square(y - y_med))
r2 = 1 - (rss / ss_total)
print(f'R² is : {r2}')
# Out:
# The average error is: 0.13349540531635284
# MSE: 0.0266413614153862
# RMSE: 0.1632218062877655
# R² is : 0.8931385278701782
