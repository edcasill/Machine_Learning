# %%
import pandas as pd
import jax
import jax.numpy as jnp
from sklearn.datasets import load_breast_cancer

# %%
data = load_breast_cancer()
bc_data = pd.DataFrame(data.data, columns=data.feature_names)
bc_data['target'] = data.target
bc_data['target'] = bc_data['target'].astype(int)
bc_data['diagnosis'] = bc_data['target'].map({ 0: 'malign', 1: 'benign'})

# %%
bc_data.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst perimeter  worst area  worst smoothness  \
# 0                 0.07871  ...           184.60      2019.0            0.1622
# 1                 0.05667  ...           158.80      1956.0            0.1238
# 2                 0.05999  ...           152.50      1709.0            0.1444
# 3                 0.09744  ...            98.87       567.7            0.2098
# 4                 0.05883  ...           152.20      1575.0            0.1374
#
#    worst compactness  worst concavity  worst concave points  worst symmetry  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    worst fractal dimension  target  diagnosis
# 0                  0.11890       0     malign
# 1                  0.08902       0     malign
# 2                  0.08758       0     malign
# 3                  0.17300       0     malign
# 4                  0.07678       0     malign
#
# [5 rows x 32 columns]

# %%
X_wo_diagnosis = bc_data.drop(['target', 'diagnosis'], axis=1).astype(float).values
y_diagnosis = bc_data['target'].astype(float).values

# %%
# creates te seed for random numbers befor spliting the data
seed = jax.random.PRNGKey(73)
index = jnp.arange(len(X_wo_diagnosis))
index_shuffle = jax.random.permutation(seed, index)

# %%
X_shuffle = X_wo_diagnosis[index_shuffle]
y_shuffle = y_diagnosis[index_shuffle]

# %%
# separate %90 data for training
len(X_wo_diagnosis)
X_training = jnp.array([])
y_training = jnp.array([])
for i in range(512):
    X_training[i] = X_wo_diagnosis[i].copy()
    #y_training = y_training[i].copy()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-4233904608.py in <cell line: 0>()
#       4 y_training = jnp.array([])
#       5 for i in range(512):
# ----> 6     X_training[i].append(X_wo_diagnosis[i])
#       7     #y_training = y_training[i].copy()
#
# /usr/local/lib/python3.12/dist-packages/jax/_src/array.py in __getitem__(self, idx)
#     384             out.aval, sharding, [out], committed=False, _skip_checks=True)
#     385
# --> 386     return indexing.rewriting_take(self, idx)
#     387
#     388   def __iter__(self):
#
# /usr/local/lib/python3.12/dist-packages/jax/_src/numpy/indexing.py in rewriting_take(arr, idx, indices_are_sorted, unique_indices, mode, fill_value, normalize_indices, out_sharding)
#     663                      axes=out_sharding.mesh.explicit_axes,  # type: ignore
#     664                      )(arr, dynamic_idx)
# --> 665   return internal_gather(arr, dynamic_idx)
#     666
#     667
#
# /usr/local/lib/python3.12/dist-packages/jax/_src/numpy/indexing.py in _gather(arr, dynamic_idx, treedef, static_idx, indices_are_sorted, unique_indices, mode, fill_value, normalize_indices)
#     672             unique_indices, mode, fill_value, normalize_indices):
#     673   idx = merge_static_and_dynamic_indices(treedef, static_idx, dynamic_idx)
# --> 674   indexer = index_to_gather(
#     675       np.shape(arr), idx, core.typeof(arr).sharding,
#     676       normalize_indices=normalize_indices)  # shared with _scatter_update
#
# /usr/local/lib/python3.12/dist-packages/jax/_src/numpy/indexing.py in index_to_gather(x_shape, idx, x_sharding, normalize_indices)
#     928       if core.definitely_equal(x_shape[x_axis], 0):
#     929         # XLA gives error when indexing into an axis of size 0
# --> 930         raise IndexError(f"index is out of bounds for axis {x_axis} with size 0")
#     931       i = _normalize_index(i, x_shape[x_axis]) if normalize_indices else i
#     932       i_converted = lax.convert_element_type(i, index_dtype)
#
# IndexError: index is out of bounds for axis 0 with size 0

# %%
X_training
# Out:
# array([1.481e+01, 1.470e+01, 9.466e+01, 6.807e+02, 8.472e-02, 5.016e-02,
#        3.416e-02, 2.541e-02, 1.659e-01, 5.348e-02, 2.182e-01, 6.232e-01,
#        1.677e+00, 2.072e+01, 6.708e-03, 1.197e-02, 1.482e-02, 1.056e-02,
#        1.580e-02, 1.779e-03, 1.561e+01, 1.758e+01, 1.017e+02, 7.602e+02,
#        1.139e-01, 1.011e-01, 1.101e-01, 7.955e-02, 2.334e-01, 6.142e-02])

# %%
mid_vector = jnp.ones((X_wo_diagnosis.shape[0], 1))
X_aug = jnp.concatenate([mid_vector, jnp.array(X_wo_diagnosis)], axis=1)
y = jnp.array(y_diagnosis)
print(X_aug.shape)
# Out:
# (569, 31)

# %%
XtX = X_aug.T @ X_aug # @ is the dot product, and is equal to use jnp.dot()
Xty = X_aug.T @ y
beta = jnp.linalg.solve(XtX, Xty) # linalg is linear algebra. It uses decomposition to solve the equation instead to use the direct inv

# %%
# beta

# %%
y_hat = X_aug @ beta
y_hat
# Out:
# Array([-4.46199775e-02,  1.57956362e-01, -1.31289959e-01, -1.91767693e-01,
#         1.65051579e-01,  3.01050663e-01,  1.50126934e-01,  3.67954075e-01,
#         3.01634848e-01, -1.54515386e-01,  4.52479720e-01,  1.40955001e-01,
#         3.58264744e-01,  5.42231441e-01,  3.74186397e-01,  6.39593601e-03,
#         1.99750304e-01, -1.62641257e-02, -6.85929060e-02,  6.72656178e-01,
#         1.02791131e+00,  1.12658191e+00,  2.65199423e-01,  1.52276754e-02,
#        -1.56616807e-01, -1.81586415e-01,  7.12091327e-02,  1.05504870e-01,
#         4.54057753e-03,  4.64961380e-01, -6.38715029e-02,  8.48129094e-02,
#        -1.09492987e-01,  4.44120169e-03,  8.23694244e-02,  1.06506452e-01,
#         4.10221487e-01,  1.00699592e+00,  7.27141500e-01,  4.37157243e-01,
#         6.74050629e-01,  5.68757951e-01, -2.03502417e-01,  3.31049949e-01,
#         3.41685176e-01, -7.03067482e-02,  1.29127371e+00,  1.86356544e-01,
#         8.88967276e-01,  6.88415885e-01,  9.57031012e-01,  9.28875744e-01,
#         9.27657366e-01,  3.32130075e-01,  4.42858458e-01,  8.26240718e-01,
#        -7.74753094e-03,  2.26660788e-01,  9.57023144e-01,  1.15616667e+00,
#         1.10712290e+00,  1.15268135e+00,  1.30742460e-01,  1.10197449e+00,
#         1.17173307e-01,  3.35868895e-01,  9.81709540e-01,  8.99870396e-01,
#         8.66217136e-01,  9.38021958e-01,  1.28160238e-01,  1.25047922e+00,
#        -1.22211546e-01,  6.06016994e-01,  8.75212371e-01,  1.85993493e-01,
#         8.62055898e-01,  2.22575426e-01, -1.94474101e-01,  9.32584345e-01,
#         8.02257538e-01,  3.97904724e-01, -3.36199880e-01,  2.01787829e-01,
#         8.15198481e-01, -4.47567105e-02,  5.05668879e-01, -2.84284949e-01,
#         6.57159686e-01,  6.63997650e-01,  7.72977829e-01,  4.97198373e-01,
#         7.26737320e-01,  8.48459482e-01,  2.44100958e-01, -1.25169754e-05,
#         9.70894158e-01,  1.02409089e+00,  8.99100661e-01,  4.79373068e-01,
#         4.03414845e-01,  1.42302978e+00,  8.43580365e-01,  1.00962651e+00,
#         1.13498461e+00,  1.71288848e-01,  6.88599467e-01,  9.88504291e-01,
#        -4.75414395e-01,  6.87331080e-01,  9.52641308e-01,  7.16315687e-01,
#         8.47099662e-01,  1.12713337e+00,  1.08379984e+00,  8.38430405e-01,
#         1.38942766e+00,  1.33878827e-01, -1.40683338e-01,  2.16639221e-01,
#         8.25217843e-01,  1.65287703e-01,  1.03522742e+00,  1.12792695e+00,
#         5.19398928e-01,  7.21528709e-01, -1.01722777e-02,  7.80084372e-01,
#         6.82019413e-01, -2.68913507e-02,  9.72229838e-01,  1.29547238e-01,
#         7.99915850e-01,  7.25519598e-01,  8.09658706e-01,  6.50442541e-01,
#         7.22657800e-01,  8.05672944e-01,  8.57042551e-01,  1.04635406e+00,
#        -3.53320837e-02, -5.04708290e-03,  8.15888464e-01,  8.81601036e-01,
#         7.82618403e-01,  6.41841710e-01,  6.94655895e-01,  9.77129221e-01,
#         2.46829689e-02,  6.50194108e-01,  9.43830729e-01,  7.41449416e-01,
#         7.30890274e-01,  8.65562022e-01,  1.08911169e+00,  8.86636794e-01,
#         7.48040140e-01,  9.49216843e-01,  1.03621078e+00,  4.33504105e-01,
#         1.01845300e+00,  7.12902188e-01,  8.22152972e-01,  9.08479512e-01,
#         7.11887002e-01,  8.29144776e-01,  7.82088459e-01, -1.47111833e-01,
#         8.30134034e-01,  4.84848171e-01,  7.61851072e-01,  7.40099728e-01,
#         2.35736191e-01,  1.00997043e+00,  8.29710484e-01,  7.19791055e-01,
#         7.10022807e-01,  8.77039254e-01,  1.18987918e-01,  1.52862072e-02,
#         8.30926418e-01,  2.48945549e-01,  8.62047195e-01, -1.57102585e-01,
#         1.16812158e+00,  9.70472097e-01,  9.46289480e-01,  8.52385998e-01,
#         6.46671474e-01,  2.17934906e-01,  9.61335778e-01,  8.88568759e-01,
#         2.43081123e-01,  7.44388163e-01,  6.27907872e-01,  9.30129468e-01,
#         1.60003424e-01,  1.07118011e-01,  9.05823410e-01,  8.56484234e-01,
#         9.36442256e-01, -1.10532999e-01,  1.13417590e+00,  7.09540725e-01,
#         1.04424524e+00,  1.15521884e+00,  7.55919576e-01,  9.39293504e-01,
#         6.95336759e-01,  9.72817361e-01,  7.84565985e-01,  8.46176624e-01,
#         8.75362754e-01,  1.64748728e-01,  1.06411815e+00,  7.37993717e-02,
#         5.73325098e-01,  7.38106728e-01,  1.01449203e+00,  1.17236090e+00,
#         1.11581886e+00,  4.97792363e-01,  6.21551096e-01,  7.85588801e-01,
#         9.51159179e-01,  7.68477798e-01,  1.15110326e+00,  1.02229702e+00,
#         1.04730964e+00,  7.89368093e-01,  1.11614192e+00,  1.01628733e+00,
#         7.14100540e-01,  1.13290823e+00,  7.46411383e-01,  8.76544595e-01,
#         1.20058966e+00,  1.02297151e+00,  9.32893276e-01,  8.22394431e-01,
#         6.94342971e-01,  1.10452819e+00, -2.10204482e-01, -1.43334627e-01,
#        -2.88774967e-01,  3.47176790e-02,  4.31305319e-01, -5.62403083e-01,
#         1.18105984e+00], dtype=float32)

# %%
res = y - y_hat
print(f'The average error is: {jnp.mean(jnp.abs(res))}')
mse = jnp.mean(jnp.power(res, 2))
rmse = jnp.sqrt(mse)
print(f'MSE: {mse}')
print(f'RMSE: {rmse}')
rss = jnp.sum(jnp.square(res))
y_med = jnp.mean(y)
ss_total = jnp.sum(jnp.square(y - y_med))
r2 = 1 - (rss / ss_total)
print(f'R² is : {r2}')
# Out:
# The average error is: 0.18057730793952942
# MSE: 0.05275509133934975
# RMSE: 0.2296847701072693
# R² is : 0.7743242979049683

# %%
y_labeled = ["benign" if val > 0.5 else "malign" for val in y_hat]

# %%
y_labeled
# Out:
# ['malign',
#  'malign',
#  'malign',
#  'malign',
#  'malign',
#  'malign',
#  'malign',
#  'malign',
#  'malign',
#  'malign',
#  'malign',
#  'malign',
#  'malign',
#  'benign',
#  'malign',
#  'malign',
#  'malign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'malign',
#  'malign',
#  'malign',
#  'malign',
#  'malign',
#  'malign',
#  'malign',
#  'malign',
#  'malign',
#  'malign',
#  'malign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'malign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'malign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'malign',
#  'malign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'malign',
#  'malign',
#  'benign',
#  'malign',
#  'malign',
#  'malign',
#  'malign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'malign',
#  'malign',
#  'malign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'malign',
#  'malign',
#  'malign',
#  'malign',
#  'benign']
