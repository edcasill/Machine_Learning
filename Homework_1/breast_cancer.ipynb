# %% [markdown]
# # Breast cancer

# %%
import pandas as pd
import jax
import jax.numpy as jnp
from sklearn.datasets import load_breast_cancer

# %% [markdown]
# ## Load data

# %%
data = load_breast_cancer()
bc_data = pd.DataFrame(data.data, columns=data.feature_names)
bc_data['target'] = data.target
bc_data['target'] = bc_data['target'].astype(int)
bc_data['diagnosis'] = bc_data['target'].map({ 0: 'malign', 1: 'benign'})

# %%
bc_data.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst perimeter  worst area  worst smoothness  \
# 0                 0.07871  ...           184.60      2019.0            0.1622
# 1                 0.05667  ...           158.80      1956.0            0.1238
# 2                 0.05999  ...           152.50      1709.0            0.1444
# 3                 0.09744  ...            98.87       567.7            0.2098
# 4                 0.05883  ...           152.20      1575.0            0.1374
#
#    worst compactness  worst concavity  worst concave points  worst symmetry  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    worst fractal dimension  target  diagnosis
# 0                  0.11890       0     malign
# 1                  0.08902       0     malign
# 2                  0.08758       0     malign
# 3                  0.17300       0     malign
# 4                  0.07678       0     malign
#
# [5 rows x 32 columns]

# %%
X_wo_diagnosis = bc_data.drop(['target', 'diagnosis'], axis=1).astype(float).values
y_diagnosis = bc_data['target'].astype(float).values

# %% [markdown]
# ## Create seed and separate data

# %%
# creates te seed for random numbers befor spliting the data
seed = jax.random.PRNGKey(73)
index = jnp.arange(len(X_wo_diagnosis))
index_shuffle = jax.random.permutation(seed, index)

# %%
X_shuffle = X_wo_diagnosis[index_shuffle]
y_shuffle = y_diagnosis[index_shuffle]
split_index = int(len(X_shuffle) * 0.9) # calculate %90 of the total data

# %%
# separate %90 data for training
X_training = X_shuffle[:split_index]
y_training = y_shuffle[:split_index]

# data for test
X_test = X_shuffle[split_index:]
y_test = y_shuffle[split_index:]

# %%
X_training
# Out:
# array([[1.316e+01, 2.054e+01, 8.406e+01, ..., 4.195e-02, 2.687e-01,
#         7.429e-02],
#        [1.189e+01, 1.835e+01, 7.732e+01, ..., 1.138e-01, 3.397e-01,
#         8.365e-02],
#        [1.791e+01, 2.102e+01, 1.244e+02, ..., 1.964e-01, 3.245e-01,
#         1.198e-01],
#        ...,
#        [1.499e+01, 2.211e+01, 9.753e+01, ..., 1.308e-01, 3.163e-01,
#         9.251e-02],
#        [1.218e+01, 1.408e+01, 7.725e+01, ..., 1.852e-02, 2.293e-01,
#         6.037e-02],
#        [1.025e+01, 1.618e+01, 6.652e+01, ..., 9.744e-02, 2.608e-01,
#         9.702e-02]])

# %% [markdown]
# ## Augmented Vector on training data

# %%
mid_vector = jnp.ones((X_training.shape[0], 1))
X_aug = jnp.concatenate([mid_vector, jnp.array(X_training)], axis=1)
y = jnp.array(y_training)
print(X_aug.shape)
# Out:
# (512, 31)

# %%
XtX = X_aug.T @ X_aug # @ is the dot product, and is equal to use jnp.dot()
Xty = X_aug.T @ y
beta = jnp.linalg.solve(XtX, Xty) # linalg is linear algebra. It uses decomposition to solve the equation instead to use the direct inv

# %% [markdown]
# ## Estimation

# %%
#         1.05881453e+00,  9.19595659e-01,  1.16262746e+00,  1.87577546e-01,
#        -8.96857977e-02,  6.91092372e-01,  7.58531809e-01,  8.90865624e-01,
#         8.83001804e-01,  6.46582067e-01,  9.03063178e-01,  9.42717791e-01,
#         1.02256489e+00,  9.08846259e-01,  6.52419090e-01,  1.24496996e+00,
#         9.45906758e-01, -1.23576522e-02, -1.17648676e-01,  7.70187140e-01,
#         7.28103518e-02,  8.09887409e-01,  8.36168766e-01,  9.85198557e-01,
#         8.42003763e-01,  8.64758074e-01,  9.56963539e-01,  1.25983906e+00,
#         7.80860484e-01,  6.78910613e-01,  1.01497877e+00,  9.26997781e-01,
#         2.21416354e-01,  1.13561988e+00,  1.14079916e+00,  1.08752835e+00,
#         9.52255368e-01,  9.81843710e-01,  9.72815633e-01,  6.36233389e-01,
#         9.26469743e-01, -4.93080318e-01, -8.19046497e-02,  1.33476555e+00,
#         1.07784700e+00,  9.32415724e-01,  8.50302458e-01,  7.92602897e-01,
#         1.98076814e-01,  7.11068988e-01,  1.15227008e+00,  2.66468853e-01,
#         5.14286518e-01,  9.83932972e-01,  6.71297193e-01,  1.09933186e+00,
#         4.25997496e-01, -2.02247798e-01,  9.83077943e-01,  1.25926232e+00,
#        -3.28493357e-01, -5.68741560e-02,  1.47016287e-01,  8.96775007e-01,
#         8.85502458e-01,  6.26884878e-01, -1.26484856e-01,  7.78862953e-01,
#         3.75744820e-01,  9.07084048e-01,  8.09631467e-01,  7.07542419e-01,
#         6.79948688e-01,  2.06213504e-01,  2.30078101e-02, -1.17837667e-01,
#         8.54963839e-01,  1.00191712e+00,  7.10295796e-01, -2.25787997e-01,
#         6.22353017e-01,  1.04778838e+00,  5.28943539e-03,  6.70358062e-01,
#         5.70344925e-01,  1.15178025e+00,  8.82662833e-01,  9.14649367e-01,
#         7.15133131e-01,  2.39154547e-01,  1.34506822e-01,  8.96276534e-01,
#        -5.36596775e-03,  8.86280060e-01,  7.44298041e-01, -2.73519754e-02,
#         1.29998827e+00, -3.53909671e-01, -1.51293993e-01,  6.96654439e-01,
#         6.41996562e-01,  9.91021276e-01,  9.12571132e-01,  1.28021821e-01,
#         4.67708826e-01,  1.10388708e+00,  8.77245128e-01,  4.97586489e-01,
#         1.12954807e+00,  5.60580194e-01,  1.16391134e+00,  9.32325482e-01],      dtype=float32)

# %% [markdown]
# ## Calculate error

# %%
res = y - y_hat
print(f'The average error is: {jnp.mean(jnp.abs(res))}')
mse = jnp.mean(jnp.power(res, 2))
rmse = jnp.sqrt(mse)
print(f'MSE: {mse}')
print(f'RMSE: {rmse}')
rss = jnp.sum(jnp.square(res))
y_med = jnp.mean(y)
ss_total = jnp.sum(jnp.square(y - y_med))
r2 = 1 - (rss / ss_total)
print(f'R² is : {r2}')
# Out:
# The average error is: 0.17776329815387726
# MSE: 0.05146130174398422
# RMSE: 0.22685083746910095
# R² is : 0.7770018577575684

# %%
y_labeled = ["benign" if val > 0.5 else "malign" for val in y_hat]
y_labeled
# Out:
# ['benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'malign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'malign',
#  'benign',
#  'malign',
#  'malign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'malign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign']

# %% [markdown]
# ## Test data

# %%
mid_vector_test = jnp.ones((X_test.shape[0], 1))
X_aug_test = jnp.concatenate([mid_vector_test, X_test], axis=1)
print(X_aug.shape)
# Out:
# (512, 31)

# %%
y_hat_test = X_aug_test @ beta
y_hat_test
# Out:
# Array([ 0.42548677,  0.45497972, -0.17376447,  0.91161203,  0.41655397,
#         0.92263204,  0.86933666,  0.9924647 ,  0.04543105,  0.94417846,
#        -0.04643899,  0.98597777,  0.1416974 ,  0.987213  ,  0.81024724,
#         0.8740764 ,  0.70222694,  0.5655428 ,  0.2628293 ,  0.0621005 ,
#         1.0111322 ,  0.73150223,  0.68480504,  0.6275369 ,  0.7651396 ,
#        -0.00597739,  0.84721446,  0.7214324 , -0.44602343,  0.5742017 ,
#         0.2277796 ,  0.3692384 ,  0.65716195,  0.83835953,  0.05405688,
#        -0.0490433 ,  1.0100409 ,  0.8706694 ,  0.9212559 ,  0.14195749,
#         0.02478746, -0.19030227,  1.1477607 ,  0.89556116,  0.15860477,
#         0.42866194,  0.7360686 ,  0.8329816 ,  0.35593632,  0.76913184,
#        -0.20512974,  0.19616866,  0.9754083 ,  1.082237  ,  1.1123945 ,
#         1.3019018 ,  0.30131048], dtype=float32)

# %%
y_labeled_test = ["benign" if val > 0.5 else "malign" for val in y_hat_test]
y_labeled_test
# Out:
# ['malign',
#  'malign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'malign',
#  'benign',
#  'malign',
#  'malign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malign']

# %% [markdown]
# ## Test error

# %%
res_test = y_test - y_hat_test
print(f'The average error is: {jnp.mean(jnp.abs(res))}')
mse_test = jnp.mean(jnp.power(res, 2))
rmse_test = jnp.sqrt(mse_test)
print(f'MSE: {mse_test}')
print(f'RMSE: {rmse_test}')
rss_test = jnp.sum(jnp.square(res_test))
y_med_test = jnp.mean(y_test)
ss_total_test = jnp.sum(jnp.square(y_test - y_med_test))
r2_test = 1 - (rss_test / ss_total_test)
print(f'R² is : {r2}')
# Out:
# The average error is: 0.17776329815387726
# MSE: 0.05146130174398422
# RMSE: 0.22685083746910095
# R² is : 0.7770018577575684

# %% [markdown]
# ## Precision and Accuracy

# %% [markdown]
# ### Confusion matrix

# %%
# aplying binning, where 1 is benign and 0 malign
y_pred = jnp.where(y_hat_test > 0.5, 1, 0)

# true positive
tp = jnp.sum((y_pred == 1) & (y_test == 1))

#true negative
tn = jnp.sum((y_pred == 0) & (y_test == 0))

#false positive
fp = jnp.sum((y_pred == 1) & (y_test == 0))

#false negative
fn = jnp.sum((y_pred == 0) & (y_test == 1))

# %%
presicion = tp / (tp + fp)
accuracy = (tp + tn) / (tp + tn + fp + fn)
print(f'Precision: {presicion}')
print(f'Accuracy: {accuracy}')
# Out:
# Precision: 0.9090909361839294
# Accuracy: 0.9473684430122375
